# %% [markdown]
# <a href="https://colab.research.google.com/github/ddAdoro/AI-Assignment-SCT314-C004-0594-2026/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-n558y5_3
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-n558y5_3
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=2a539406c6f9778cd17dcacff60df02446c522b19cd3c86d289a08d027edcef5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nalmorgx/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
nn.Flatten(),
nn.Linear(40, 100),
nn.ReLU(),
nn.Linear(100, 100),
nn.ReLU(),
nn.Linear(100, 10))

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 1.638181, train error 63.75,  val loss 1.687760, percent error 66.90
# Epoch     1, train loss 1.373464, train error 51.25,  val loss 1.497856, percent error 59.30
# Epoch     2, train loss 1.184877, train error 43.45,  val loss 1.359287, percent error 51.60
# Epoch     3, train loss 1.041170, train error 36.12,  val loss 1.272099, percent error 48.60
# Epoch     4, train loss 0.903876, train error 30.80,  val loss 1.184054, percent error 45.50
# Epoch     5, train loss 0.820776, train error 28.15,  val loss 1.193180, percent error 45.00
# Epoch     6, train loss 0.711420, train error 23.22,  val loss 1.116348, percent error 43.80
# Epoch     7, train loss 0.643889, train error 21.32,  val loss 1.145304, percent error 41.30
# Epoch     8, train loss 0.578001, train error 19.53,  val loss 1.141024, percent error 40.50
# Epoch     9, train loss 0.520968, train error 17.45,  val loss 1.132472, percent error 40.20
# Epoch    10, train loss 0.447329, train error 13.85,  val loss 1.074958, percent error 38.60
# Epoch    11, train loss 0.435297, train error 15.28,  val loss 1.126282, percent error 38.60
# Epoch    12, train loss 0.350457, train error 11.03,  val loss 1.125879, percent error 38.20
# Epoch    13, train loss 0.300719, train error 9.28,  val loss 1.096472, percent error 37.50
# Epoch    14, train loss 0.295406, train error 9.45,  val loss 1.186530, percent error 39.00
# Epoch    15, train loss 0.246427, train error 7.03,  val loss 1.196558, percent error 36.70
# Epoch    16, train loss 0.225207, train error 6.47,  val loss 1.248461, percent error 38.20
# Epoch    17, train loss 0.202379, train error 5.70,  val loss 1.259637, percent error 36.60
# Epoch    18, train loss 0.187736, train error 5.85,  val loss 1.332217, percent error 35.80
# Epoch    19, train loss 0.184844, train error 5.28,  val loss 1.364658, percent error 37.90
# Epoch    20, train loss 0.085672, train error 0.80,  val loss 1.237489, percent error 34.50
# Epoch    21, train loss 0.065133, train error 0.25,  val loss 1.243679, percent error 35.00
# Epoch    22, train loss 0.061218, train error 0.25,  val loss 1.256791, percent error 35.00
# Epoch    23, train loss 0.050828, train error 0.07,  val loss 1.278069, percent error 34.70
# Epoch    24, train loss 0.044421, train error 0.03,  val loss 1.295581, percent error 34.80
# Epoch    25, train loss 0.043093, train error 0.03,  val loss 1.322868, percent error 35.60
# Epoch    26, train loss 0.037774, train error 0.03,  val loss 1.338880, percent error 35.30
# Epoch    27, train loss 0.034823, train error 0.00,  val loss 1.359845, percent error 34.40
# Epoch    28, train loss 0.031608, train error 0.00,  val loss 1.367564, percent error 34.30
# Epoch    29, train loss 0.029993, train error 0.00,  val loss 1.388050, percent error 34.30
# Epoch    30, train loss 0.028024, train error 0.00,  val loss 1.404644, percent error 34.90
# Epoch    31, train loss 0.026026, train error 0.00,  val loss 1.418275, percent error 35.00
# Epoch    32, train loss 0.024068, train error 0.00,  val loss 1.427427, percent error 34.60
# Epoch    33, train loss 0.023068, train error 0.00,  val loss 1.444795, percent error 35.10
# Epoch    34, train loss 0.021440, train error 0.00,  val loss 1.453799, percent error 35.10
# Epoch    35, train loss 0.020337, train error 0.00,  val loss 1.471941, percent error 35.20
# Epoch    36, train loss 0.019261, train error 0.00,  val loss 1.475983, percent error 34.90
# Epoch    37, train loss 0.018437, train error 0.00,  val loss 1.492185, percent error 34.70
# Epoch    38, train loss 0.017395, train error 0.00,  val loss 1.497422, percent error 35.20
# Epoch    39, train loss 0.016805, train error 0.00,  val loss 1.510113, percent error 34.70
# Epoch    40, train loss 0.016061, train error 0.00,  val loss 1.512000, percent error 35.10
# Epoch    41, train loss 0.015702, train error 0.00,  val loss 1.519454, percent error 35.00
# Epoch    42, train loss 0.015475, train error 0.00,  val loss 1.518850, percent error 34.80
# Epoch    43, train loss 0.015042, train error 0.00,  val loss 1.526216, percent error 35.10
# Epoch    44, train loss 0.014755, train error 0.00,  val loss 1.529825, percent error 34.50
# Epoch    45, train loss 0.014478, train error 0.00,  val loss 1.537575, percent error 34.80
# Epoch    46, train loss 0.014168, train error 0.00,  val loss 1.541691, percent error 35.30
# Epoch    47, train loss 0.013917, train error 0.00,  val loss 1.545932, percent error 35.00
# Epoch    48, train loss 0.013638, train error 0.00,  val loss 1.550151, percent error 34.90
# Epoch    49, train loss 0.013413, train error 0.00,  val loss 1.554291, percent error 34.80
# Epoch    50, train loss 0.013255, train error 0.00,  val loss 1.559533, percent error 35.10
# Epoch    51, train loss 0.012928, train error 0.00,  val loss 1.560953, percent error 35.20
# Epoch    52, train loss 0.012709, train error 0.00,  val loss 1.568483, percent error 35.00
# Epoch    53, train loss 0.012454, train error 0.00,  val loss 1.568832, percent error 34.90
# Epoch    54, train loss 0.012240, train error 0.00,  val loss 1.574220, percent error 34.80
# Epoch    55, train loss 0.012055, train error 0.00,  val loss 1.579361, percent error 34.90
# Epoch    56, train loss 0.011840, train error 0.00,  val loss 1.583212, percent error 34.90
# Epoch    57, train loss 0.011648, train error 0.00,  val loss 1.586623, percent error 34.70
# Epoch    58, train loss 0.011517, train error 0.00,  val loss 1.591323, percent error 34.90
# Epoch    59, train loss 0.011277, train error 0.00,  val loss 1.598740, percent error 35.00
# Epoch    60, train loss 0.011158, train error 0.00,  val loss 1.595806, percent error 34.80
# Epoch    61, train loss 0.011057, train error 0.00,  val loss 1.599011, percent error 34.80
# Epoch    62, train loss 0.010968, train error 0.00,  val loss 1.600281, percent error 34.80
# Epoch    63, train loss 0.010884, train error 0.00,  val loss 1.601803, percent error 34.80
# Epoch    64, train loss 0.010803, train error 0.00,  val loss 1.604169, percent error 34.90
# Epoch    65, train loss 0.010721, train error 0.00,  val loss 1.605687, percent error 34.90
# Epoch    66, train loss 0.010633, train error 0.00,  val loss 1.608160, percent error 34.80
# Epoch    67, train loss 0.010555, train error 0.00,  val loss 1.609704, percent error 34.80
# Epoch    68, train loss 0.010476, train error 0.00,  val loss 1.611366, percent error 34.90
# Epoch    69, train loss 0.010397, train error 0.00,  val loss 1.612729, percent error 34.90
# Epoch    70, train loss 0.010323, train error 0.00,  val loss 1.615186, percent error 34.90
# Epoch    71, train loss 0.010246, train error 0.00,  val loss 1.615341, percent error 35.00
# Epoch    72, train loss 0.010165, train error 0.00,  val loss 1.618600, percent error 35.00
# Epoch    73, train loss 0.010095, train error 0.00,  val loss 1.620704, percent error 34.70
# Epoch    74, train loss 0.010018, train error 0.00,  val loss 1.622159, percent error 34.90
# Epoch    75, train loss 0.009949, train error 0.00,  val loss 1.624430, percent error 34.80
# Epoch    76, train loss 0.009880, train error 0.00,  val loss 1.625526, percent error 34.70
# Epoch    77, train loss 0.009810, train error 0.00,  val loss 1.627207, percent error 34.90
# Epoch    78, train loss 0.009737, train error 0.00,  val loss 1.629240, percent error 34.70
# Epoch    79, train loss 0.009667, train error 0.00,  val loss 1.630024, percent error 35.00
# Epoch    80, train loss 0.009627, train error 0.00,  val loss 1.631145, percent error 35.00
# Epoch    81, train loss 0.009593, train error 0.00,  val loss 1.631634, percent error 34.80
# Epoch    82, train loss 0.009559, train error 0.00,  val loss 1.633176, percent error 34.80
# Epoch    83, train loss 0.009525, train error 0.00,  val loss 1.634126, percent error 34.90
# Epoch    84, train loss 0.009493, train error 0.00,  val loss 1.635244, percent error 34.80
# Epoch    85, train loss 0.009460, train error 0.00,  val loss 1.635595, percent error 34.70
# Epoch    86, train loss 0.009427, train error 0.00,  val loss 1.636343, percent error 34.90
# Epoch    87, train loss 0.009395, train error 0.00,  val loss 1.637423, percent error 34.80
# Epoch    88, train loss 0.009363, train error 0.00,  val loss 1.638281, percent error 34.90
# Epoch    89, train loss 0.009330, train error 0.00,  val loss 1.638854, percent error 34.90
# Epoch    90, train loss 0.009299, train error 0.00,  val loss 1.639491, percent error 35.00
# Epoch    91, train loss 0.009267, train error 0.00,  val loss 1.640247, percent error 34.90
# Epoch    92, train loss 0.009235, train error 0.00,  val loss 1.641384, percent error 35.00
# Epoch    93, train loss 0.009205, train error 0.00,  val loss 1.641817, percent error 34.90
# Epoch    94, train loss 0.009173, train error 0.00,  val loss 1.643011, percent error 34.90
# Epoch    95, train loss 0.009142, train error 0.00,  val loss 1.643657, percent error 35.00
# Epoch    96, train loss 0.009112, train error 0.00,  val loss 1.644470, percent error 34.90
# Epoch    97, train loss 0.009081, train error 0.00,  val loss 1.645575, percent error 35.00
# Epoch    98, train loss 0.009052, train error 0.00,  val loss 1.646334, percent error 35.10
# Epoch    99, train loss 0.009021, train error 0.00,  val loss 1.646920, percent error 35.00
