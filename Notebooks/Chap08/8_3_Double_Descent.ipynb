# %% [markdown]
# <a href="https://colab.research.google.com/github/ddAdoro/AI-Assignment-SCT314-C004-0594-2026/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-8b4w1rof
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-8b4w1rof
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=c4412bb8d6213e216336a47d15f8cd490d7111993eae875dd3431d30d32d67b5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8rhke7jo/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.306000, train error 89.78,  test loss 2.305527, test error 90.05
# Epoch   100, train loss 2.059459, train error 78.70,  test loss 1.986959, test error 76.57
# Epoch   200, train loss 1.923037, train error 71.53,  test loss 1.775002, test error 68.22
# Epoch   300, train loss 1.908988, train error 70.85,  test loss 1.743623, test error 67.57
# Epoch   400, train loss 1.903654, train error 71.07,  test loss 1.734316, test error 68.60
# Epoch   500, train loss 1.909661, train error 71.85,  test loss 1.723716, test error 69.47
# Epoch   600, train loss 1.904482, train error 70.62,  test loss 1.746370, test error 67.70
# Epoch   700, train loss 1.910922, train error 72.47,  test loss 1.763479, test error 69.55
# Epoch   800, train loss 1.898935, train error 71.35,  test loss 1.746001, test error 68.93
# Epoch   900, train loss 1.900904, train error 71.60,  test loss 1.751422, test error 68.80
# Training model with   4 hidden variables
# Epoch     0, train loss 2.218984, train error 86.97,  test loss 2.193481, test error 87.20
# Epoch   100, train loss 1.822297, train error 68.00,  test loss 1.676320, test error 66.62
# Epoch   200, train loss 1.765081, train error 65.57,  test loss 1.625776, test error 64.57
# Epoch   300, train loss 1.748875, train error 64.57,  test loss 1.605183, test error 63.25
# Epoch   400, train loss 1.728281, train error 63.97,  test loss 1.588273, test error 62.35
# Epoch   500, train loss 1.732155, train error 63.70,  test loss 1.597799, test error 63.47
# Epoch   600, train loss 1.717512, train error 62.97,  test loss 1.586387, test error 61.42
# Epoch   700, train loss 1.709388, train error 62.88,  test loss 1.572103, test error 61.22
# Epoch   800, train loss 1.720882, train error 63.33,  test loss 1.592133, test error 62.72
# Epoch   900, train loss 1.710631, train error 62.62,  test loss 1.578479, test error 61.97
# Training model with   6 hidden variables
# Epoch     0, train loss 2.205019, train error 86.88,  test loss 2.169596, test error 86.20
# Epoch   100, train loss 1.712341, train error 61.78,  test loss 1.542056, test error 59.50
# Epoch   200, train loss 1.642074, train error 58.62,  test loss 1.461989, test error 56.40
# Epoch   300, train loss 1.628734, train error 58.62,  test loss 1.454255, test error 55.58
# Epoch   400, train loss 1.613142, train error 57.38,  test loss 1.464087, test error 56.05
# Epoch   500, train loss 1.604838, train error 57.72,  test loss 1.465812, test error 55.67
# Epoch   600, train loss 1.599490, train error 58.10,  test loss 1.478263, test error 56.38
# Epoch   700, train loss 1.600062, train error 57.15,  test loss 1.492035, test error 55.95
# Epoch   800, train loss 1.602511, train error 57.45,  test loss 1.481593, test error 57.20
# Epoch   900, train loss 1.593210, train error 56.83,  test loss 1.488912, test error 56.28
# Training model with   8 hidden variables
# Epoch     0, train loss 2.263489, train error 84.43,  test loss 2.263249, test error 84.40
# Epoch   100, train loss 1.651353, train error 59.70,  test loss 1.528069, test error 59.62
# Epoch   200, train loss 1.574949, train error 54.53,  test loss 1.426780, test error 54.95
# Epoch   300, train loss 1.551136, train error 54.28,  test loss 1.410419, test error 54.42
# Epoch   400, train loss 1.525961, train error 52.42,  test loss 1.385185, test error 52.30
# Epoch   500, train loss 1.516064, train error 52.70,  test loss 1.379275, test error 52.10
# Epoch   600, train loss 1.510121, train error 52.60,  test loss 1.381021, test error 51.88
# Epoch   700, train loss 1.499965, train error 52.17,  test loss 1.368601, test error 50.65
# Epoch   800, train loss 1.478669, train error 50.03,  test loss 1.327343, test error 48.28
# Epoch   900, train loss 1.459117, train error 49.62,  test loss 1.295563, test error 46.67
# Training model with  10 hidden variables
# Epoch     0, train loss 2.263685, train error 84.32,  test loss 2.253431, test error 84.72
# Epoch   100, train loss 1.585687, train error 55.53,  test loss 1.437172, test error 55.38
# Epoch   200, train loss 1.532793, train error 53.83,  test loss 1.408891, test error 54.35
# Epoch   300, train loss 1.488567, train error 52.65,  test loss 1.416752, test error 55.05
# Epoch   400, train loss 1.477295, train error 52.67,  test loss 1.434407, test error 54.62
# Epoch   500, train loss 1.471166, train error 52.38,  test loss 1.447909, test error 55.28
# Epoch   600, train loss 1.470315, train error 52.67,  test loss 1.443004, test error 54.75
# Epoch   700, train loss 1.464449, train error 52.47,  test loss 1.444431, test error 55.35
# Epoch   800, train loss 1.464534, train error 52.12,  test loss 1.456230, test error 55.22
# Epoch   900, train loss 1.471802, train error 52.47,  test loss 1.464713, test error 55.67
# Training model with  14 hidden variables
# Epoch     0, train loss 2.230379, train error 83.65,  test loss 2.207086, test error 82.10
# Epoch   100, train loss 1.396985, train error 46.03,  test loss 1.251308, test error 46.33
# Epoch   200, train loss 1.328951, train error 43.72,  test loss 1.252963, test error 46.30
# Epoch   300, train loss 1.298659, train error 43.42,  test loss 1.278497, test error 47.42
# Epoch   400, train loss 1.285743, train error 43.85,  test loss 1.305345, test error 47.67
# Epoch   500, train loss 1.274211, train error 43.95,  test loss 1.323044, test error 47.83
# Epoch   600, train loss 1.261381, train error 42.47,  test loss 1.329731, test error 48.28
# Epoch   700, train loss 1.257006, train error 42.17,  test loss 1.351132, test error 48.22
# Epoch   800, train loss 1.249955, train error 42.80,  test loss 1.367493, test error 48.60
# Epoch   900, train loss 1.242095, train error 42.17,  test loss 1.364351, test error 47.90
# Training model with  18 hidden variables
# Epoch     0, train loss 2.108425, train error 78.40,  test loss 2.052050, test error 77.38
# Epoch   100, train loss 1.330552, train error 43.78,  test loss 1.265662, test error 46.85
# Epoch   200, train loss 1.237650, train error 40.92,  test loss 1.315977, test error 47.58
# Epoch   300, train loss 1.189018, train error 40.17,  test loss 1.352383, test error 47.35
# Epoch   400, train loss 1.158254, train error 38.53,  test loss 1.409700, test error 47.92
# Epoch   500, train loss 1.143349, train error 38.67,  test loss 1.458840, test error 48.53
# Epoch   600, train loss 1.138901, train error 38.10,  test loss 1.497414, test error 49.75
# Epoch   700, train loss 1.143377, train error 39.70,  test loss 1.520126, test error 50.03
# Epoch   800, train loss 1.111919, train error 37.80,  test loss 1.522085, test error 49.22
# Epoch   900, train loss 1.110027, train error 37.58,  test loss 1.557770, test error 49.75
# Training model with  22 hidden variables
# Epoch     0, train loss 2.141248, train error 79.55,  test loss 2.081085, test error 79.50
# Epoch   100, train loss 1.300011, train error 43.92,  test loss 1.357773, test error 51.35
# Epoch   200, train loss 1.188634, train error 40.15,  test loss 1.412955, test error 51.75
# Epoch   300, train loss 1.128205, train error 38.20,  test loss 1.446457, test error 51.15
# Epoch   400, train loss 1.087825, train error 36.40,  test loss 1.503881, test error 51.70
# Epoch   500, train loss 1.066977, train error 35.68,  test loss 1.580251, test error 53.17
# Epoch   600, train loss 1.040657, train error 35.53,  test loss 1.615083, test error 52.70
# Epoch   700, train loss 1.045309, train error 35.55,  test loss 1.651086, test error 53.15
# Epoch   800, train loss 1.026923, train error 35.15,  test loss 1.717974, test error 54.17
# Epoch   900, train loss 1.007158, train error 34.45,  test loss 1.696986, test error 53.40
# Training model with  26 hidden variables
# Epoch     0, train loss 2.118744, train error 77.90,  test loss 2.069677, test error 77.90
# Epoch   100, train loss 1.158893, train error 38.30,  test loss 1.304263, test error 49.33
# Epoch   200, train loss 1.022321, train error 33.30,  test loss 1.425096, test error 51.05
# Epoch   300, train loss 0.951496, train error 30.43,  test loss 1.558973, test error 51.62
# Epoch   400, train loss 0.898282, train error 29.93,  test loss 1.672226, test error 52.08
# Epoch   500, train loss 0.867557, train error 28.95,  test loss 1.786318, test error 52.92
# Epoch   600, train loss 0.877331, train error 30.15,  test loss 1.897885, test error 54.50
# Epoch   700, train loss 0.808289, train error 27.97,  test loss 1.942479, test error 52.83
# Epoch   800, train loss 0.808190, train error 27.88,  test loss 2.002702, test error 53.08
# Epoch   900, train loss 0.807804, train error 28.03,  test loss 2.074216, test error 53.65
# Training model with  30 hidden variables
# Epoch     0, train loss 2.231148, train error 82.38,  test loss 2.234728, test error 83.72
# Epoch   100, train loss 1.114876, train error 37.50,  test loss 1.352569, test error 49.65
# Epoch   200, train loss 0.945188, train error 32.20,  test loss 1.576580, test error 51.47
# Epoch   300, train loss 0.840729, train error 28.95,  test loss 1.805330, test error 53.67
# Epoch   400, train loss 0.795471, train error 27.95,  test loss 1.985242, test error 53.67
# Epoch   500, train loss 0.751870, train error 25.55,  test loss 2.151489, test error 53.55
# Epoch   600, train loss 0.736150, train error 24.85,  test loss 2.316984, test error 54.55
# Epoch   700, train loss 0.714086, train error 24.38,  test loss 2.440935, test error 54.62
# Epoch   800, train loss 0.689184, train error 23.60,  test loss 2.550439, test error 54.35
# Epoch   900, train loss 0.687836, train error 24.15,  test loss 2.765996, test error 56.40
# Training model with  35 hidden variables
# Epoch     0, train loss 2.142221, train error 78.12,  test loss 2.130766, test error 78.93
# Epoch   100, train loss 1.010783, train error 31.97,  test loss 1.435666, test error 50.35
# Epoch   200, train loss 0.810658, train error 26.85,  test loss 1.755988, test error 52.03
# Epoch   300, train loss 0.693513, train error 23.40,  test loss 2.138675, test error 53.58
# Epoch   400, train loss 0.653669, train error 22.07,  test loss 2.394417, test error 55.58
# Epoch   500, train loss 0.543473, train error 17.40,  test loss 2.714218, test error 55.85
# Epoch   600, train loss 0.528750, train error 17.68,  test loss 3.082409, test error 56.58
# Epoch   700, train loss 0.487105, train error 17.03,  test loss 3.358197, test error 56.17
# Epoch   800, train loss 0.474576, train error 16.30,  test loss 3.593928, test error 56.60
# Epoch   900, train loss 0.466196, train error 16.22,  test loss 3.873925, test error 57.15
# Training model with  40 hidden variables
# Epoch     0, train loss 2.097935, train error 79.28,  test loss 2.057486, test error 79.45
# Epoch   100, train loss 0.952998, train error 31.93,  test loss 1.457196, test error 52.12
# Epoch   200, train loss 0.664888, train error 21.70,  test loss 1.922038, test error 53.78
# Epoch   300, train loss 0.509887, train error 16.78,  test loss 2.588937, test error 56.33
# Epoch   400, train loss 0.420663, train error 14.28,  test loss 3.311203, test error 57.72
# Epoch   500, train loss 0.362407, train error 12.78,  test loss 4.063738, test error 56.80
# Epoch   600, train loss 0.304883, train error 10.00,  test loss 4.724529, test error 57.47
# Epoch   700, train loss 0.313662, train error 11.22,  test loss 5.514917, test error 57.47
# Epoch   800, train loss 0.218924, train error 6.97,  test loss 6.116346, test error 58.20
# Epoch   900, train loss 0.240803, train error 8.47,  test loss 6.896429, test error 58.25
# Training model with  45 hidden variables
# Epoch     0, train loss 2.118909, train error 77.78,  test loss 2.106101, test error 79.03
# Epoch   100, train loss 0.780182, train error 25.03,  test loss 1.549572, test error 51.08
# Epoch   200, train loss 0.478282, train error 14.88,  test loss 2.346702, test error 55.12
# Epoch   300, train loss 0.335240, train error 10.62,  test loss 3.588876, test error 57.80
# Epoch   400, train loss 0.209970, train error 6.85,  test loss 4.988418, test error 57.90
# Epoch   500, train loss 0.215533, train error 6.62,  test loss 6.320966, test error 57.62
# Epoch   600, train loss 0.127927, train error 4.43,  test loss 7.421963, test error 57.65
# Epoch   700, train loss 0.014950, train error 0.00,  test loss 8.603446, test error 57.53
# Epoch   800, train loss 0.007011, train error 0.00,  test loss 9.328127, test error 57.30
# Epoch   900, train loss 0.005199, train error 0.00,  test loss 9.818629, test error 57.25
# Training model with  50 hidden variables
# Epoch     0, train loss 2.067992, train error 77.12,  test loss 2.006197, test error 74.72
# Epoch   100, train loss 0.701853, train error 21.88,  test loss 1.631322, test error 51.72
# Epoch   200, train loss 0.314164, train error 7.95,  test loss 2.797142, test error 55.95
# Epoch   300, train loss 0.150089, train error 3.32,  test loss 4.357514, test error 56.35
# Epoch   400, train loss 0.028695, train error 0.03,  test loss 6.013646, test error 57.53
# Epoch   500, train loss 0.012876, train error 0.00,  test loss 7.004952, test error 58.03
# Epoch   600, train loss 0.008263, train error 0.00,  test loss 7.652822, test error 58.00
# Epoch   700, train loss 0.005872, train error 0.00,  test loss 8.119970, test error 57.60
# Epoch   800, train loss 0.004462, train error 0.00,  test loss 8.509436, test error 57.83
# Epoch   900, train loss 0.003586, train error 0.00,  test loss 8.814970, test error 57.53
# Training model with  55 hidden variables
# Epoch     0, train loss 2.092026, train error 78.07,  test loss 2.057664, test error 78.82
# Epoch   100, train loss 0.641724, train error 19.95,  test loss 1.678076, test error 51.70
# Epoch   200, train loss 0.241545, train error 6.18,  test loss 3.053689, test error 54.00
# Epoch   300, train loss 0.046645, train error 0.18,  test loss 4.863729, test error 55.22
# Epoch   400, train loss 0.013810, train error 0.00,  test loss 5.950972, test error 55.45
# Epoch   500, train loss 0.008081, train error 0.00,  test loss 6.605360, test error 55.28
# Epoch   600, train loss 0.005525, train error 0.00,  test loss 7.069961, test error 55.28
# Epoch   700, train loss 0.004162, train error 0.00,  test loss 7.425725, test error 55.45
# Epoch   800, train loss 0.003277, train error 0.00,  test loss 7.719953, test error 55.42
# Epoch   900, train loss 0.002707, train error 0.00,  test loss 7.964079, test error 55.45
# Training model with  60 hidden variables
# Epoch     0, train loss 2.095654, train error 77.75,  test loss 2.056980, test error 75.97
# Epoch   100, train loss 0.502148, train error 14.07,  test loss 1.741496, test error 50.53
# Epoch   200, train loss 0.094254, train error 0.78,  test loss 3.455717, test error 54.08
# Epoch   300, train loss 0.019361, train error 0.00,  test loss 4.754029, test error 54.30
# Epoch   400, train loss 0.009328, train error 0.00,  test loss 5.431375, test error 53.88
# Epoch   500, train loss 0.005865, train error 0.00,  test loss 5.875629, test error 53.92
# Epoch   600, train loss 0.004178, train error 0.00,  test loss 6.195233, test error 53.88
# Epoch   700, train loss 0.003214, train error 0.00,  test loss 6.454451, test error 53.88
# Epoch   800, train loss 0.002587, train error 0.00,  test loss 6.665950, test error 53.92
# Epoch   900, train loss 0.002144, train error 0.00,  test loss 6.848870, test error 53.90
# Training model with  70 hidden variables
# Epoch     0, train loss 2.029944, train error 76.32,  test loss 1.972826, test error 75.62
# Epoch   100, train loss 0.360281, train error 8.40,  test loss 1.933364, test error 51.35
# Epoch   200, train loss 0.032983, train error 0.00,  test loss 3.566677, test error 54.33
# Epoch   300, train loss 0.011129, train error 0.00,  test loss 4.343725, test error 54.42
# Epoch   400, train loss 0.006223, train error 0.00,  test loss 4.786897, test error 54.33
# Epoch   500, train loss 0.004185, train error 0.00,  test loss 5.091525, test error 54.28
# Epoch   600, train loss 0.003097, train error 0.00,  test loss 5.326747, test error 54.05
# Epoch   700, train loss 0.002431, train error 0.00,  test loss 5.514997, test error 54.10
# Epoch   800, train loss 0.001988, train error 0.00,  test loss 5.672443, test error 54.05
# Epoch   900, train loss 0.001668, train error 0.00,  test loss 5.807490, test error 54.03
# Training model with  80 hidden variables
# Epoch     0, train loss 2.010749, train error 74.53,  test loss 1.955371, test error 74.82
# Epoch   100, train loss 0.237044, train error 4.55,  test loss 2.204831, test error 52.67
# Epoch   200, train loss 0.020332, train error 0.00,  test loss 3.694789, test error 53.78
# Epoch   300, train loss 0.008020, train error 0.00,  test loss 4.288569, test error 53.62
# Epoch   400, train loss 0.004732, train error 0.00,  test loss 4.639259, test error 53.38
# Epoch   500, train loss 0.003271, train error 0.00,  test loss 4.890305, test error 53.55
# Epoch   600, train loss 0.002455, train error 0.00,  test loss 5.080927, test error 53.62
# Epoch   700, train loss 0.001952, train error 0.00,  test loss 5.235174, test error 53.40
# Epoch   800, train loss 0.001605, train error 0.00,  test loss 5.369588, test error 53.50
# Epoch   900, train loss 0.001358, train error 0.00,  test loss 5.480876, test error 53.45
# Training model with  90 hidden variables
# Epoch     0, train loss 2.020673, train error 74.72,  test loss 1.999247, test error 77.07
# Epoch   100, train loss 0.136757, train error 1.18,  test loss 2.181069, test error 51.25
# Epoch   200, train loss 0.013813, train error 0.00,  test loss 3.161823, test error 51.38
# Epoch   300, train loss 0.006213, train error 0.00,  test loss 3.571116, test error 51.70
# Epoch   400, train loss 0.003821, train error 0.00,  test loss 3.824487, test error 51.80
# Epoch   500, train loss 0.002699, train error 0.00,  test loss 4.005669, test error 52.03
# Epoch   600, train loss 0.002057, train error 0.00,  test loss 4.148829, test error 51.97
# Epoch   700, train loss 0.001648, train error 0.00,  test loss 4.265987, test error 51.95
# Epoch   800, train loss 0.001367, train error 0.00,  test loss 4.365632, test error 52.12
# Epoch   900, train loss 0.001162, train error 0.00,  test loss 4.452567, test error 52.15
# Training model with 100 hidden variables
# Epoch     0, train loss 1.966306, train error 73.80,  test loss 1.885437, test error 72.65
# Epoch   100, train loss 0.081271, train error 0.07,  test loss 2.233639, test error 50.40
# Epoch   200, train loss 0.011962, train error 0.00,  test loss 3.002155, test error 50.75
# Epoch   300, train loss 0.005666, train error 0.00,  test loss 3.345620, test error 50.78
# Epoch   400, train loss 0.003551, train error 0.00,  test loss 3.562955, test error 50.97
# Epoch   500, train loss 0.002527, train error 0.00,  test loss 3.723179, test error 51.00
# Epoch   600, train loss 0.001937, train error 0.00,  test loss 3.846382, test error 51.00
# Epoch   700, train loss 0.001558, train error 0.00,  test loss 3.949308, test error 50.92
# Epoch   800, train loss 0.001294, train error 0.00,  test loss 4.035813, test error 50.88
# Epoch   900, train loss 0.001102, train error 0.00,  test loss 4.112200, test error 50.97
# Training model with 120 hidden variables
# Epoch     0, train loss 1.970256, train error 73.47,  test loss 1.909779, test error 74.50
# Epoch   100, train loss 0.051840, train error 0.00,  test loss 2.156986, test error 49.35
# Epoch   200, train loss 0.009643, train error 0.00,  test loss 2.758690, test error 49.50
# Epoch   300, train loss 0.004763, train error 0.00,  test loss 3.028348, test error 49.55
# Epoch   400, train loss 0.003042, train error 0.00,  test loss 3.197735, test error 49.50
# Epoch   500, train loss 0.002194, train error 0.00,  test loss 3.326000, test error 49.58
# Epoch   600, train loss 0.001695, train error 0.00,  test loss 3.425743, test error 49.60
# Epoch   700, train loss 0.001371, train error 0.00,  test loss 3.509280, test error 49.50
# Epoch   800, train loss 0.001145, train error 0.00,  test loss 3.579250, test error 49.55
# Epoch   900, train loss 0.000978, train error 0.00,  test loss 3.640863, test error 49.42
# Training model with 140 hidden variables
# Epoch     0, train loss 1.960270, train error 73.28,  test loss 1.893205, test error 74.00
# Epoch   100, train loss 0.036588, train error 0.00,  test loss 2.145569, test error 49.88
# Epoch   200, train loss 0.008223, train error 0.00,  test loss 2.626964, test error 49.95
# Epoch   300, train loss 0.004228, train error 0.00,  test loss 2.854074, test error 50.15
# Epoch   400, train loss 0.002744, train error 0.00,  test loss 3.003800, test error 50.20
# Epoch   500, train loss 0.001996, train error 0.00,  test loss 3.116801, test error 50.12
# Epoch   600, train loss 0.001549, train error 0.00,  test loss 3.204466, test error 50.08
# Epoch   700, train loss 0.001257, train error 0.00,  test loss 3.278766, test error 50.12
# Epoch   800, train loss 0.001052, train error 0.00,  test loss 3.340966, test error 50.03
# Epoch   900, train loss 0.000901, train error 0.00,  test loss 3.396505, test error 50.12
# Training model with 160 hidden variables
# Epoch     0, train loss 1.961103, train error 72.47,  test loss 1.897781, test error 74.03
# Epoch   100, train loss 0.028097, train error 0.00,  test loss 2.082960, test error 48.08
# Epoch   200, train loss 0.007112, train error 0.00,  test loss 2.480454, test error 48.17
# Epoch   300, train loss 0.003752, train error 0.00,  test loss 2.677819, test error 47.92
# Epoch   400, train loss 0.002465, train error 0.00,  test loss 2.806911, test error 47.95
# Epoch   500, train loss 0.001807, train error 0.00,  test loss 2.903338, test error 47.88
# Epoch   600, train loss 0.001411, train error 0.00,  test loss 2.981704, test error 47.95
# Epoch   700, train loss 0.001150, train error 0.00,  test loss 3.046563, test error 48.10
# Epoch   800, train loss 0.000966, train error 0.00,  test loss 3.101681, test error 47.92
# Epoch   900, train loss 0.000829, train error 0.00,  test loss 3.150284, test error 47.88
# Training model with 180 hidden variables
# Epoch     0, train loss 1.913663, train error 70.82,  test loss 1.842467, test error 72.05
# Epoch   100, train loss 0.023782, train error 0.00,  test loss 2.058283, test error 48.83
# Epoch   200, train loss 0.006504, train error 0.00,  test loss 2.409694, test error 48.70
# Epoch   300, train loss 0.003490, train error 0.00,  test loss 2.589456, test error 48.88
# Epoch   400, train loss 0.002311, train error 0.00,  test loss 2.707536, test error 48.78
# Epoch   500, train loss 0.001700, train error 0.00,  test loss 2.797952, test error 48.83
# Epoch   600, train loss 0.001332, train error 0.00,  test loss 2.870462, test error 48.90
# Epoch   700, train loss 0.001087, train error 0.00,  test loss 2.930396, test error 48.80
# Epoch   800, train loss 0.000915, train error 0.00,  test loss 2.981595, test error 48.95
# Epoch   900, train loss 0.000786, train error 0.00,  test loss 3.026697, test error 49.05
# Training model with 200 hidden variables
# Epoch     0, train loss 1.910620, train error 69.57,  test loss 1.847832, test error 72.25
# Epoch   100, train loss 0.020990, train error 0.00,  test loss 1.959192, test error 47.67
# Epoch   200, train loss 0.006060, train error 0.00,  test loss 2.257326, test error 47.58
# Epoch   300, train loss 0.003301, train error 0.00,  test loss 2.416336, test error 47.58
# Epoch   400, train loss 0.002204, train error 0.00,  test loss 2.521654, test error 47.47
# Epoch   500, train loss 0.001629, train error 0.00,  test loss 2.602113, test error 47.58
# Epoch   600, train loss 0.001280, train error 0.00,  test loss 2.666810, test error 47.62
# Epoch   700, train loss 0.001047, train error 0.00,  test loss 2.720587, test error 47.55
# Epoch   800, train loss 0.000882, train error 0.00,  test loss 2.766940, test error 47.50
# Epoch   900, train loss 0.000759, train error 0.00,  test loss 2.807628, test error 47.47
# Training model with 250 hidden variables
# Epoch     0, train loss 1.860317, train error 67.62,  test loss 1.787815, test error 67.95
# Epoch   100, train loss 0.017241, train error 0.00,  test loss 1.881648, test error 47.33
# Epoch   200, train loss 0.005374, train error 0.00,  test loss 2.128549, test error 47.00
# Epoch   300, train loss 0.002986, train error 0.00,  test loss 2.257519, test error 47.00
# Epoch   400, train loss 0.002017, train error 0.00,  test loss 2.346615, test error 46.88
# Epoch   500, train loss 0.001500, train error 0.00,  test loss 2.415009, test error 47.00
# Epoch   600, train loss 0.001183, train error 0.00,  test loss 2.469954, test error 46.92
# Epoch   700, train loss 0.000971, train error 0.00,  test loss 2.516147, test error 46.75
# Epoch   800, train loss 0.000819, train error 0.00,  test loss 2.555364, test error 46.88
# Epoch   900, train loss 0.000706, train error 0.00,  test loss 2.590329, test error 46.80
# Training model with 300 hidden variables
# Epoch     0, train loss 1.892501, train error 69.88,  test loss 1.817875, test error 71.22
# Epoch   100, train loss 0.014318, train error 0.00,  test loss 1.914852, test error 47.10
# Epoch   200, train loss 0.004767, train error 0.00,  test loss 2.142171, test error 46.42
# Epoch   300, train loss 0.002691, train error 0.00,  test loss 2.263941, test error 46.40
# Epoch   400, train loss 0.001834, train error 0.00,  test loss 2.348229, test error 46.42
# Epoch   500, train loss 0.001373, train error 0.00,  test loss 2.412632, test error 46.30
# Epoch   600, train loss 0.001088, train error 0.00,  test loss 2.465018, test error 46.45
# Epoch   700, train loss 0.000896, train error 0.00,  test loss 2.508833, test error 46.22
# Epoch   800, train loss 0.000758, train error 0.00,  test loss 2.546860, test error 46.17
# Epoch   900, train loss 0.000655, train error 0.00,  test loss 2.579596, test error 46.17
# Training model with 400 hidden variables
# Epoch     0, train loss 1.908373, train error 69.00,  test loss 1.839352, test error 71.50
# Epoch   100, train loss 0.011506, train error 0.00,  test loss 1.800599, test error 46.53
# Epoch   200, train loss 0.004105, train error 0.00,  test loss 1.982361, test error 46.08
# Epoch   300, train loss 0.002385, train error 0.00,  test loss 2.082421, test error 45.90
# Epoch   400, train loss 0.001644, train error 0.00,  test loss 2.153431, test error 45.80
# Epoch   500, train loss 0.001239, train error 0.00,  test loss 2.206766, test error 45.88
# Epoch   600, train loss 0.000987, train error 0.00,  test loss 2.250009, test error 45.85
# Epoch   700, train loss 0.000816, train error 0.00,  test loss 2.286665, test error 45.85
# Epoch   800, train loss 0.000693, train error 0.00,  test loss 2.318450, test error 45.80
# Epoch   900, train loss 0.000600, train error 0.00,  test loss 2.346045, test error 45.72

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
