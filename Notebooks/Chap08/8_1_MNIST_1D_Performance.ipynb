# %% [markdown]
# <a href="https://colab.research.google.com/github/ddAdoro/AI-Assignment-SCT314-C004-0594-2026/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-5s2i1a1f
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-5s2i1a1f
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=b8711af3da79e6fd05da3356a96a7bb5d28fe28bcf29cb85cb5db55e75ebf715
#   Stored in directory: /tmp/pip-ephem-wheel-cache-v6cz2_s9/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(
    torch.nn.Linear(D_i, D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_o)
)


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, nn.Linear):
        nn.init.kaiming_uniform_(layer_in.weight)
        # Optionally initialize biases to zero
        if layer_in.bias is not None:
            nn.init.zeros_(layer_in.bias)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.744133, train error 70.55,  test loss 1.758948, test error 74.10
# Epoch     1, train loss 1.683042, train error 67.03,  test loss 1.716582, test error 71.20
# Epoch     2, train loss 1.657321, train error 65.88,  test loss 1.692534, test error 69.40
# Epoch     3, train loss 1.639410, train error 64.53,  test loss 1.690758, test error 70.20
# Epoch     4, train loss 1.633638, train error 64.88,  test loss 1.679985, test error 68.00
# Epoch     5, train loss 1.626894, train error 64.60,  test loss 1.661811, test error 67.60
# Epoch     6, train loss 1.619638, train error 63.80,  test loss 1.679754, test error 70.30
# Epoch     7, train loss 1.617865, train error 63.92,  test loss 1.674418, test error 68.80
# Epoch     8, train loss 1.624860, train error 64.78,  test loss 1.669980, test error 67.50
# Epoch     9, train loss 1.613198, train error 64.78,  test loss 1.687292, test error 70.30
# Epoch    10, train loss 1.598288, train error 62.47,  test loss 1.658417, test error 67.50
# Epoch    11, train loss 1.598271, train error 63.15,  test loss 1.655987, test error 67.30
# Epoch    12, train loss 1.597629, train error 62.70,  test loss 1.659176, test error 66.80
# Epoch    13, train loss 1.598542, train error 62.85,  test loss 1.656582, test error 67.70
# Epoch    14, train loss 1.596000, train error 62.58,  test loss 1.657859, test error 67.50
# Epoch    15, train loss 1.599879, train error 63.17,  test loss 1.664070, test error 68.10
# Epoch    16, train loss 1.595588, train error 62.88,  test loss 1.659912, test error 67.10
# Epoch    17, train loss 1.596481, train error 62.67,  test loss 1.652762, test error 67.00
# Epoch    18, train loss 1.597328, train error 62.30,  test loss 1.658862, test error 67.00
# Epoch    19, train loss 1.597749, train error 62.40,  test loss 1.656426, test error 67.30
# Epoch    20, train loss 1.593134, train error 62.25,  test loss 1.654934, test error 66.70
# Epoch    21, train loss 1.591951, train error 62.95,  test loss 1.657818, test error 67.20
# Epoch    22, train loss 1.591497, train error 62.25,  test loss 1.656584, test error 67.40
# Epoch    23, train loss 1.592145, train error 62.42,  test loss 1.653643, test error 66.90
# Epoch    24, train loss 1.591208, train error 62.35,  test loss 1.655450, test error 68.20
# Epoch    25, train loss 1.590766, train error 62.83,  test loss 1.653905, test error 67.40
# Epoch    26, train loss 1.590989, train error 62.72,  test loss 1.656285, test error 67.50
# Epoch    27, train loss 1.590585, train error 62.22,  test loss 1.653772, test error 67.40
# Epoch    28, train loss 1.589888, train error 62.58,  test loss 1.651731, test error 66.70
# Epoch    29, train loss 1.590816, train error 62.62,  test loss 1.656838, test error 67.50
# Epoch    30, train loss 1.589212, train error 62.50,  test loss 1.653815, test error 67.20
# Epoch    31, train loss 1.589103, train error 62.65,  test loss 1.652722, test error 67.30
# Epoch    32, train loss 1.589044, train error 62.53,  test loss 1.652586, test error 67.10
# Epoch    33, train loss 1.588989, train error 62.85,  test loss 1.652178, test error 67.00
# Epoch    34, train loss 1.589096, train error 62.40,  test loss 1.654897, test error 68.40
# Epoch    35, train loss 1.588980, train error 62.88,  test loss 1.654475, test error 67.20
# Epoch    36, train loss 1.588784, train error 62.80,  test loss 1.653487, test error 67.70
# Epoch    37, train loss 1.588698, train error 62.72,  test loss 1.654486, test error 67.20
# Epoch    38, train loss 1.588841, train error 62.45,  test loss 1.652124, test error 66.70
# Epoch    39, train loss 1.588805, train error 62.47,  test loss 1.652790, test error 66.80
# Epoch    40, train loss 1.588581, train error 62.75,  test loss 1.652528, test error 67.10
# Epoch    41, train loss 1.588447, train error 62.35,  test loss 1.654245, test error 67.20
# Epoch    42, train loss 1.588435, train error 62.72,  test loss 1.653076, test error 66.90
# Epoch    43, train loss 1.588427, train error 62.55,  test loss 1.654270, test error 67.10
# Epoch    44, train loss 1.588386, train error 62.90,  test loss 1.653843, test error 67.10
# Epoch    45, train loss 1.588337, train error 62.47,  test loss 1.653212, test error 67.30
# Epoch    46, train loss 1.588326, train error 62.70,  test loss 1.653218, test error 67.10
# Epoch    47, train loss 1.588304, train error 62.67,  test loss 1.653439, test error 67.40
# Epoch    48, train loss 1.588270, train error 62.75,  test loss 1.654278, test error 67.40
# Epoch    49, train loss 1.588268, train error 62.70,  test loss 1.653052, test error 66.90

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way? Yes Will the final result be a good estimate of the true test performance? Yes, but repeatedly evaluating on the same test set during this process can lead to overfitting to that specific test set.
